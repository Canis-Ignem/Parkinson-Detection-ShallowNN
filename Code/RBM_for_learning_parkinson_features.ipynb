# %% [markdown]
# # Using an RMB to learn parkinson features
#
# In this notebook I will tackle the problem of letting an RMB learn features that I will use to train an MLP in order to solve the Parkinson detection problem. Please note that this notebook contains only one of the three proposed solutions, in order to get a complete view you should check the other notebook and the documentation.

# %% [markdown]
# ## Feature selection
#
# The main goal is to let the RMB learn the features but in previous attemps when giving it all the data and etting it trainit didn't manage to learn anything. So I will be reusing most of the previously used feature selection techniques. If you have any doubts pls check the other notebook.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.ndimage import convolve
from sklearn import metrics
from sklearn.linear_model import Perceptron
from sklearn.model_selection import train_test_split
from sklearn.neural_network import BernoulliRBM
from sklearn.pipeline import Pipeline
from sklearn.base import clone
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import featureExtractionRBM as fe
import pandas as pd
import numpy as np
import glob

# %% [markdown]
# ## Aproach to feature selection
# I will follow the same procedure that was followed in the other notebook with the exception that I will not be using the variance or the test_id for the RMB. One of the main points I want to stress here is the fact that I am making splits of the same exact size for both the control and the Parkinson data, this is crucial if we are to keep the integrity of the testing process. The amount of splits has gone down too in order to make the process faster.

# %%
control_path = "Data/control"
parkinson_path = "Data/parkinson"


def getFiles(path):
    all_files = glob.glob(path + "/*.txt")
    data = []

    for file in all_files:
        df = pd.read_csv(file,sep=";")
        data.append(df)
    
    return data
         

def extractFeatures(df):
    features = []
    features.append(np.argmax( df.values[:,0]) - np.argmin( df.values[:,0]))
    features.append(np.argmax( df.values[:,1]) - np.argmin( df.values[:,1]))
    features.append(np.argmax( df.values[:,2]) - np.argmin( df.values[:,2]))
    features.append(np.argmax( df.values[:,3]) - np.argmin( df.values[:,3]))
    features.append(np.argmax( df.values[:,4]) - np.argmin( df.values[:,4]))
    return features
    

def getControlFeatures():
    control_data = []
    control = getFiles(control_path)
    for i in control:
        new_df = splitByTest(i)
        for k in range(new_df.shape[0]):
            last_df = np.array_split(i,40)
            for j in last_df:
                control_data.append(extractFeatures(j))
    return pd.DataFrame(control_data)


def getParkinsonFeatures():
    parkinson_data = []
    parkinson = getFiles(parkinson_path)
    for i in parkinson:
        new_df = splitByTest(i)
        for k in range(new_df.shape[0]):
            last_df = np.array_split(i,40)
            for j in last_df:
                parkinson_data.append(extractFeatures(j))
    return pd.DataFrame(parkinson_data)


def getClasses(control, parkinson):
    classes = []
    for i in range(control.shape[0]):
        classes.append(0)
    for i in range(parkinson.shape[0]):
        classes.append(1)
    res = np.array(classes)

    return res

def splitByTest(df):
    data = []
    test = df.values[0][6]
    split = []
    cont = 0
    for i in range(df.shape[0]):
        if df.values[i][6] == test:
            split.append(df.values[i])
        else:
            aux = pd.DataFrame(split)
            data.append(aux)
            split = []
            test = df.values[i][6]
            split.append(df.values[i])
    data.append(split)
    return pd.DataFrame(data)

# %% [markdown]
# ## RBM and MLP pipeline
#
# I decided to used the RMB that is abailable in SKlearn, which is the Bernoulli Restricted Blotzmann machine, I will create a pipeline with this RBM and skelarn MLPClassifier.

# %% [markdown]
# ## Let's set up the RBM's parameters

# %%
rbm = BernoulliRBM( verbose=True)

rbm.learning_rate = 0.0002
rbm.n_iter = 300

rbm.n_components = 200

# %% [markdown]
# ## Setting up the MLP and the pipeline
#
# The alpha I chose was the default. For the layers I used two layers of sizes 70 and 10. For the solver Adam worked the best and the activation function will be relu. The learning rate a settled on is 0.0005 and it will train for 5k epochs with a momentum of 0.7.

# %%
mlp = MLPClassifier(alpha=1e-08, hidden_layer_sizes=(70,10),solver='adam',
                    activation='relu',  learning_rate_init = .0005,
                    max_iter=5000, momentum = 0.7)

rbm_features_classifier = Pipeline(steps=[('rbm', rbm), ('MLP', mlp)])

# %% [markdown]
#  Lets gather our data and train the pipeline. This procedures are similar to the ones showed in the previous notebook

# %%
data = getControlFeatures()
park = getParkinsonFeatures()

all_data = np.concatenate((data,park),axis= 0)
target = fe.getClasses(data,park)

train_data, test_data, train_target, test_target = train_test_split(all_data,target, test_size= 0.3, random_state=30 )

rbm_features_classifier.fit(train_data, train_target)
# Out:
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -107231.14, time = 0.09s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -219247.59, time = 0.23s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -327501.41, time = 0.23s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -450910.63, time = 0.22s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -542645.88, time = 0.21s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -657398.11, time = 0.21s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -757120.09, time = 0.22s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -945923.95, time = 0.24s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -972718.21, time = 0.21s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -1105794.55, time = 0.22s
# [BernoulliRBM] Iteration 11, pseudo-likelihood = -1238721.10, time = 0.21s
# [BernoulliRBM] Iteration 12, pseudo-likelihood = -1385335.46, time = 0.22s
# [BernoulliRBM] Iteration 13, pseudo-likelihood = -1490246.37, time = 0.23s
# [BernoulliRBM] Iteration 14, pseudo-likelihood = -1613348.58, time = 0.22s
# [BernoulliRBM] Iteration 15, pseudo-likelihood = -1623857.02, time = 0.22s
# [BernoulliRBM] Iteration 16, pseudo-likelihood = -1759708.66, time = 0.22s
# [BernoulliRBM] Iteration 17, pseudo-likelihood = -1881374.36, time = 0.22s
# [BernoulliRBM] Iteration 18, pseudo-likelihood = -1905068.28, time = 0.22s
# [BernoulliRBM] Iteration 19, pseudo-likelihood = -2118019.06, time = 0.21s
# [BernoulliRBM] Iteration 20, pseudo-likelihood = -2251218.37, time = 0.22s
# [BernoulliRBM] Iteration 21, pseudo-likelihood = -2334961.11, time = 0.22s
# [BernoulliRBM] Iteration 22, pseudo-likelihood = -2367017.10, time = 0.22s
# [BernoulliRBM] Iteration 23, pseudo-likelihood = -2588111.62, time = 0.22s
# [BernoulliRBM] Iteration 24, pseudo-likelihood = -2650811.89, time = 0.23s
# [BernoulliRBM] Iteration 25, pseudo-likelihood = -2752642.65, time = 0.22s
# [BernoulliRBM] Iteration 26, pseudo-likelihood = -2853098.03, time = 0.18s
# [BernoulliRBM] Iteration 170, pseudo-likelihood = -19664497.19, time = 0.26s
# [BernoulliRBM] Iteration 171, pseudo-likelihood = -19846580.03, time = 0.23s
# [BernoulliRBM] Iteration 172, pseudo-likelihood = -19841599.54, time = 0.22s
# [BernoulliRBM] Iteration 173, pseudo-likelihood = -19800422.55, time = 0.23s
# [BernoulliRBM] Iteration 174, pseudo-likelihood = -21319449.61, time = 0.23s
# [BernoulliRBM] Iteration 175, pseudo-likelihood = -19026344.92, time = 0.22s
# [BernoulliRBM] Iteration 176, pseudo-likelihood = -19406812.08, time = 0.21s
# [BernoulliRBM] Iteration 177, pseudo-likelihood = -19926787.67, time = 0.21s
# [BernoulliRBM] Iteration 178, pseudo-likelihood = -19149206.29, time = 0.22s
# [BernoulliRBM] Iteration 179, pseudo-likelihood = -20167898.60, time = 0.23s
# [BernoulliRBM] Iteration 180, pseudo-likelihood = -21531517.62, time = 0.22s
# [BernoulliRBM] Iteration 181, pseudo-likelihood = -20485332.12, time = 0.23s
# [BernoulliRBM] Iteration 182, pseudo-likelihood = -21971801.13, time = 0.22s
# [BernoulliRBM] Iteration 183, pseudo-likelihood = -20043547.72, time = 0.22s
# [BernoulliRBM] Iteration 184, pseudo-likelihood = -20541439.00, time = 0.22s
# [BernoulliRBM] Iteration 185, pseudo-likelihood = -22173591.60, time = 0.22s
# [BernoulliRBM] Iteration 186, pseudo-likelihood = -21593696.62, time = 0.21s
# [BernoulliRBM] Iteration 187, pseudo-likelihood = -21242239.64, time = 0.22s
# [BernoulliRBM] Iteration 188, pseudo-likelihood = -21209598.76, time = 0.22s
# [BernoulliRBM] Iteration 189, pseudo-likelihood = -20679407.63, time = 0.21s
# [BernoulliRBM] Iteration 190, pseudo-likelihood = -21972014.76, time = 0.22s
# [BernoulliRBM] Iteration 191, pseudo-likelihood = -22263866.12, time = 0.22s
# [BernoulliRBM] Iteration 192, pseudo-likelihood = -22371218.48, time = 0.22s
# [BernoulliRBM] Iteration 193, pseudo-likelihood = -22189438.05, time = 0.22s
# [BernoulliRBM] Iteration 194, pseudo-likelihood = -22608599.13, time = 0.21s
# [BernoulliRBM] Iteration 195, pseudo-likelihood = -23275759.46, time = 0.21s
# [BernoulliRBM] Iteration 196, pseudo-likelihood = -22912249.66, time = 0.22s
# [BernoulliRBM] Iteration 197, pseudo-likelihood = -23656285.77, time = 0.22s
# [BernoulliRBM] Iteration 198, pseudo-likelihood = -22609589.97, time = 0.22s
# [BernoulliRBM] Iteration 199, pseudo-likelihood = -23024440.22, time = 0.22s
# [BernoulliRBM] Iteration 200, pseudo-likelihood = -22303989.95, time = 0.22s
# [BernoulliRBM] Iteration 201, pseudo-likelihood = -23688937.06, time = 0.22s
# [BernoulliRBM] Iteration 202, pseudo-likelihood = -21747405.94, time = 0.22s
# [BernoulliRBM] Iteration 203, pseudo-likelihood = -23362152.24, time = 0.21s
# [BernoulliRBM] Iteration 204, pseudo-likelihood = -24099890.67, time = 0.20s
# [BernoulliRBM] Iteration 205, pseudo-likelihood = -22816354.19, time = 0.22s
# [BernoulliRBM] Iteration 206, pseudo-likelihood = -23666837.93, time = 0.23s
# [BernoulliRBM] Iteration 207, pseudo-likelihood = -24360486.08, time = 0.22s
# [BernoulliRBM] Iteration 208, pseudo-likelihood = -24078182.16, time = 0.22s
# [BernoulliRBM] Iteration 209, pseudo-likelihood = -24120951.65, time = 0.25s
# [BernoulliRBM] Iteration 210, pseudo-likelihood = -23556677.16, time = 0.22s
# [BernoulliRBM] Iteration 211, pseudo-likelihood = -23342487.20, time = 0.23s
# [BernoulliRBM] Iteration 212, pseudo-likelihood = -24939568.87, time = 0.22s
# [BernoulliRBM] Iteration 213, pseudo-likelihood = -23331332.80, time = 0.22s
# [BernoulliRBM] Iteration 214, pseudo-likelihood = -24732208.44, time = 0.22s
# [BernoulliRBM] Iteration 215, pseudo-likelihood = -25889468.44, time = 0.23s
# [BernoulliRBM] Iteration 216, pseudo-likelihood = -25496255.76, time = 0.23s
# [BernoulliRBM] Iteration 217, pseudo-likelihood = -24951860.78, time = 0.22s
# [BernoulliRBM] Iteration 218, pseudo-likelihood = -26652949.03, time = 0.22s
# [BernoulliRBM] Iteration 219, pseudo-likelihood = -25283236.71, time = 0.21s
# [BernoulliRBM] Iteration 220, pseudo-likelihood = -24410736.66, time = 0.22s
# [BernoulliRBM] Iteration 221, pseudo-likelihood = -25544630.27, time = 0.22s
# [BernoulliRBM] Iteration 222, pseudo-likelihood = -26229721.81, time = 0.22s
# [BernoulliRBM] Iteration 223, pseudo-likelihood = -24976564.05, time = 0.22s
# [BernoulliRBM] Iteration 224, pseudo-likelihood = -26062841.53, time = 0.23s
# [BernoulliRBM] Iteration 225, pseudo-likelihood = -26004291.97, time = 0.19s
# [BernoulliRBM] Iteration 226, pseudo-likelihood = -27524362.52, time = 0.21s
# [BernoulliRBM] Iteration 227, pseudo-likelihood = -25688510.71, time = 0.23s
# [BernoulliRBM] Iteration 228, pseudo-likelihood = -27816103.55, time = 0.22s
# [BernoulliRBM] Iteration 229, pseudo-likelihood = -26443549.74, time = 0.22s
# [BernoulliRBM] Iteration 230, pseudo-likelihood = -25004219.55, time = 0.24s
# [BernoulliRBM] Iteration 231, pseudo-likelihood = -26616236.00, time = 0.19s
# [BernoulliRBM] Iteration 232, pseudo-likelihood = -26167246.01, time = 0.21s
# [BernoulliRBM] Iteration 233, pseudo-likelihood = -25634300.78, time = 0.20s
# [BernoulliRBM] Iteration 234, pseudo-likelihood = -28270379.31, time = 0.21s
# [BernoulliRBM] Iteration 235, pseudo-likelihood = -26232229.74, time = 0.21s
# [BernoulliRBM] Iteration 236, pseudo-likelihood = -27758363.48, time = 0.21s
# [BernoulliRBM] Iteration 237, pseudo-likelihood = -25250797.66, time = 0.21s
# [BernoulliRBM] Iteration 238, pseudo-likelihood = -27689409.58, time = 0.22s
# [BernoulliRBM] Iteration 239, pseudo-likelihood = -27858755.95, time = 0.22s
# [BernoulliRBM] Iteration 240, pseudo-likelihood = -27884595.89, time = 0.21s
# [BernoulliRBM] Iteration 241, pseudo-likelihood = -27336073.29, time = 0.22s
# [BernoulliRBM] Iteration 242, pseudo-likelihood = -27293509.11, time = 0.22s
# [BernoulliRBM] Iteration 243, pseudo-likelihood = -27238677.06, time = 0.23s
# [BernoulliRBM] Iteration 244, pseudo-likelihood = -28143863.76, time = 0.20s
# [BernoulliRBM] Iteration 245, pseudo-likelihood = -28134965.99, time = 0.21s
# [BernoulliRBM] Iteration 246, pseudo-likelihood = -28680650.91, time = 0.24s
# [BernoulliRBM] Iteration 247, pseudo-likelihood = -29046360.92, time = 0.22s
# [BernoulliRBM] Iteration 248, pseudo-likelihood = -28973657.55, time = 0.22s
# [BernoulliRBM] Iteration 249, pseudo-likelihood = -29552016.96, time = 0.21s
# [BernoulliRBM] Iteration 250, pseudo-likelihood = -28749102.74, time = 0.21s
# [BernoulliRBM] Iteration 251, pseudo-likelihood = -28921492.41, time = 0.22s
# [BernoulliRBM] Iteration 252, pseudo-likelihood = -28679780.65, time = 0.23s
# [BernoulliRBM] Iteration 253, pseudo-likelihood = -30804518.76, time = 0.22s
# [BernoulliRBM] Iteration 254, pseudo-likelihood = -30042268.37, time = 0.22s
# [BernoulliRBM] Iteration 255, pseudo-likelihood = -31511816.61, time = 0.26s
# [BernoulliRBM] Iteration 256, pseudo-likelihood = -30340238.47, time = 0.22s
# [BernoulliRBM] Iteration 257, pseudo-likelihood = -29313214.02, time = 0.23s
# [BernoulliRBM] Iteration 258, pseudo-likelihood = -30461304.28, time = 0.21s
# [BernoulliRBM] Iteration 259, pseudo-likelihood = -30382035.38, time = 0.21s
# [BernoulliRBM] Iteration 260, pseudo-likelihood = -31726048.59, time = 0.21s
# [BernoulliRBM] Iteration 261, pseudo-likelihood = -30707225.34, time = 0.22s
# [BernoulliRBM] Iteration 262, pseudo-likelihood = -30746815.93, time = 0.22s
# [BernoulliRBM] Iteration 263, pseudo-likelihood = -29627661.75, time = 0.23s
# [BernoulliRBM] Iteration 264, pseudo-likelihood = -31324217.38, time = 0.22s
# [BernoulliRBM] Iteration 265, pseudo-likelihood = -30273879.67, time = 0.22s
# [BernoulliRBM] Iteration 266, pseudo-likelihood = -30752084.27, time = 0.21s
# [BernoulliRBM] Iteration 267, pseudo-likelihood = -31371460.22, time = 0.21s
# [BernoulliRBM] Iteration 268, pseudo-likelihood = -32101947.22, time = 0.24s
# [BernoulliRBM] Iteration 269, pseudo-likelihood = -30843245.97, time = 0.21s
# [BernoulliRBM] Iteration 270, pseudo-likelihood = -31789290.89, time = 0.21s
# [BernoulliRBM] Iteration 271, pseudo-likelihood = -30245251.55, time = 0.21s
# [BernoulliRBM] Iteration 272, pseudo-likelihood = -30898259.58, time = 0.22s
# [BernoulliRBM] Iteration 273, pseudo-likelihood = -31570069.31, time = 0.21s
# [BernoulliRBM] Iteration 274, pseudo-likelihood = -31613853.05, time = 0.22s
# [BernoulliRBM] Iteration 275, pseudo-likelihood = -32022063.14, time = 0.21s
# [BernoulliRBM] Iteration 276, pseudo-likelihood = -31986958.06, time = 0.22s
# [BernoulliRBM] Iteration 277, pseudo-likelihood = -33501889.56, time = 0.22s
# [BernoulliRBM] Iteration 278, pseudo-likelihood = -33954455.99, time = 0.22s
# [BernoulliRBM] Iteration 279, pseudo-likelihood = -31527384.78, time = 0.24s
# [BernoulliRBM] Iteration 280, pseudo-likelihood = -33095642.37, time = 0.22s
# [BernoulliRBM] Iteration 281, pseudo-likelihood = -31695060.28, time = 0.23s
# [BernoulliRBM] Iteration 282, pseudo-likelihood = -32819269.04, time = 0.23s
# [BernoulliRBM] Iteration 283, pseudo-likelihood = -34310724.30, time = 0.23s
# [BernoulliRBM] Iteration 284, pseudo-likelihood = -34560510.17, time = 0.23s
# [BernoulliRBM] Iteration 285, pseudo-likelihood = -32943383.71, time = 0.23s
# [BernoulliRBM] Iteration 286, pseudo-likelihood = -32740400.05, time = 0.22s
# [BernoulliRBM] Iteration 287, pseudo-likelihood = -34215034.93, time = 0.22s
# [BernoulliRBM] Iteration 288, pseudo-likelihood = -33480232.64, time = 0.23s
# [BernoulliRBM] Iteration 289, pseudo-likelihood = -33748958.47, time = 0.21s
# [BernoulliRBM] Iteration 290, pseudo-likelihood = -32660516.42, time = 0.23s
# [BernoulliRBM] Iteration 291, pseudo-likelihood = -34835115.18, time = 0.22s
# [BernoulliRBM] Iteration 292, pseudo-likelihood = -34766502.37, time = 0.23s
# [BernoulliRBM] Iteration 293, pseudo-likelihood = -32112053.32, time = 0.22s
# [BernoulliRBM] Iteration 294, pseudo-likelihood = -34268072.61, time = 0.22s
# [BernoulliRBM] Iteration 295, pseudo-likelihood = -34348070.73, time = 0.22s
# [BernoulliRBM] Iteration 296, pseudo-likelihood = -35431519.91, time = 0.24s
# [BernoulliRBM] Iteration 297, pseudo-likelihood = -34449990.71, time = 0.22s
# [BernoulliRBM] Iteration 298, pseudo-likelihood = -35061070.56, time = 0.23s
# [BernoulliRBM] Iteration 299, pseudo-likelihood = -32658283.77, time = 0.23s
# [BernoulliRBM] Iteration 300, pseudo-likelihood = -36474034.05, time = 0.22s
# Pipeline(steps=[('rbm',
#                  BernoulliRBM(learning_rate=0.0002, n_components=200,
#                               n_iter=300, verbose=True)),
#                 ('MLP',
#                  MLPClassifier(alpha=1e-08, hidden_layer_sizes=(70, 10),
#                                learning_rate_init=0.0005, max_iter=5000,
#                                momentum=0.7))])

# %% [markdown]
# ## Evaluating the results
# The next step if to use our testing data and evaluate the results

# %%
Y_pred = rbm_features_classifier.predict(test_data)

print(confusion_matrix(Y_pred, test_target))
print(accuracy_score(Y_pred, test_target))
# Out:
# [[  10    3]
#  [ 425 1986]]
# 0.8234323432343235

# %%
print("MLP using RBM features:\n%s\n" % (
    metrics.classification_report(test_target, Y_pred)))
# Out:
# MLP using RBM features:
#               precision    recall  f1-score   support
#
#            0       0.77      0.02      0.04       435
#            1       0.82      1.00      0.90      1989
#
#     accuracy                           0.82      2424
#    macro avg       0.80      0.51      0.47      2424
# weighted avg       0.81      0.82      0.75      2424

# %% [markdown]
# As we can see using this approach gives us good results comparable to the one obtained with the other 2 approaches. But once again without tampering with the testing data.
